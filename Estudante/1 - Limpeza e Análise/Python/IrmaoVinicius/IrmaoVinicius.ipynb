# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\vsuar\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\vsuar\anaconda3\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pillow in c:\users\vsuar\anaconda3\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in c:\users\vsuar\anaconda3\lib\site-packages (from wordcloud) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vsuar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vsuar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vsuar\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vsuar\appdata\roaming\python\python39\site-packages (from matplotlib->wordcloud) (2.4.7)
# Requirement already satisfied: six in c:\users\vsuar\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
df = pd.read_csv('respostas.csv')
df.tail()
# Out:
#    Carimbo de data/hora Qual é seu distrito?              1) É gentil  \
# 45  05/02/2021 10:03:07         3A português  A - Concordo Totalmente
# 46  05/02/2021 10:04:46               3A-POR  A - Concordo Totalmente
# 47  05/02/2021 10:06:30              3 A POR  A - Concordo Totalmente
# 48  05/02/2021 10:15:10             03-A POR  A - Concordo Totalmente
# 49  05/02/2021 10:20:00         3A português  A - Concordo Totalmente
#
#            2) É trabalhador 3) Tem uma atitude positiva  \
# 45  A - Concordo Totalmente     A - Concordo Totalmente
# 46  A - Concordo Totalmente     A - Concordo Totalmente
# 47  A - Concordo Totalmente     A - Concordo Totalmente
# 48  A - Concordo Totalmente     A - Concordo Totalmente
# 49  A - Concordo Totalmente     A - Concordo Totalmente
#
#    4) Ouve atentamente às minhas necessidades e preocupações e interesses  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#              5) É confiável 6) Está bem preparado para ensinar  \
# 45  A - Concordo Totalmente            A - Concordo Totalmente
# 46  A - Concordo Totalmente            A - Concordo Totalmente
# 47  A - Concordo Totalmente            A - Concordo Totalmente
# 48  A - Concordo Totalmente            A - Concordo Totalmente
# 49  A - Concordo Totalmente            A - Concordo Totalmente
#
#    7) Chega e sai no horário        8) É entusiasmado  ...  \
# 45   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 46   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 47   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 48   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 49   A - Concordo Totalmente  A - Concordo Totalmente  ...
#
#    26) Este/a Instrutor/a me encoraja a falar meu idioma da missão  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#    27) Este/a Instrutor/a fala o idioma da missão o máximo possível  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#    28) Eu me sinto próximo desse Instrutor/a  \
# 45                   A - Concordo Totalmente
# 46                   A - Concordo Totalmente
# 47                   A - Concordo Totalmente
# 48                   A - Concordo Totalmente
# 49                   A - Concordo Totalmente
#
#    29) Respeito e admiro esse Instrutor/a  \
# 45                A - Concordo Totalmente
# 46                A - Concordo Totalmente
# 47                A - Concordo Totalmente
# 48                A - Concordo Totalmente
# 49                A - Concordo Totalmente
#
#    30) Este/a Instrutor/a realmente se preocupa comigo  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#    31) Este/a Instrutor/a me entende  \
# 45           A - Concordo Totalmente
# 46           A - Concordo Totalmente
# 47           A - Concordo Totalmente
# 48           A - Concordo Totalmente
# 49           A - Concordo Totalmente
#
#    32) Se não houver uma reposta que descreva seu relacionamento com este(a) instrutor(a), então comente sobre isso aqui:  \
# 45                                         Muito bom
# 46                                                NaN
# 47                                              É boa
# 48                                                NaN
# 49  Sou inteiramente grata pelas risadas, pela con...
#
#         33) O que você gosta sobre esse instrutor(a)?  \
# 45                                     Ele ri sempre
# 46                                          Tudo dele
# 47  O carinho ao explicar  o humor a vontade de en...
# 48  A alegria e o entusiasmo em ensinar o evangelh...
# 49  TUDO, mas principalmente, dos testemunhos que ...
#
#    34) Quais sugestões você tem para este(a) instrutor(a)?  \
# 45                                        Ta perfeito
# 46                          Acho que não mudaria nada
# 47                                                NaN
# 48                                                NaN
# 49  Continue sendo sorridente, diligente, atencios...
#
#    35) Comentários e Sugestões. Seu instrutor(a) verá esses comentários depois de sair, mas seu nome NÃO será divulgado.
# 45  Ele é muito inteligente, interativo, preocupad...
# 46  Irmão Vinícius,\nMuito obrigado por tudo. Sou ...
# 47                                                NaN
# 48  Obrigado por sorrir sempre, e por transmitir e...
# 49  Obrigada. Ah é, não pode esquecer que A ORAÇÃO...
#
# [5 rows x 37 columns]

# %%
def clean_district(distrito):
    if "37" in distrito:
        return "37-A POR"
    elif "16" in distrito:
        return "16-A ESP"
    elif "26" in distrito:
        return "26-A ING"
    elif "32" in distrito:
        return "32-B ING"
    elif "40" in distrito:
        return "40-B POR"
    elif "45" in distrito:
        return "45-B POR"
    else:
        return "03-A POR"

# %%
df['Qual é seu distrito?'] = df['Qual é seu distrito?'].apply(clean_district)
df.tail()
# Out:
#    Carimbo de data/hora Qual é seu distrito?              1) É gentil  \
# 45  05/02/2021 10:03:07             03-A POR  A - Concordo Totalmente
# 46  05/02/2021 10:04:46             03-A POR  A - Concordo Totalmente
# 47  05/02/2021 10:06:30             03-A POR  A - Concordo Totalmente
# 48  05/02/2021 10:15:10             03-A POR  A - Concordo Totalmente
# 49  05/02/2021 10:20:00             03-A POR  A - Concordo Totalmente
#
#            2) É trabalhador 3) Tem uma atitude positiva  \
# 45  A - Concordo Totalmente     A - Concordo Totalmente
# 46  A - Concordo Totalmente     A - Concordo Totalmente
# 47  A - Concordo Totalmente     A - Concordo Totalmente
# 48  A - Concordo Totalmente     A - Concordo Totalmente
# 49  A - Concordo Totalmente     A - Concordo Totalmente
#
#    4) Ouve atentamente às minhas necessidades e preocupações e interesses  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#              5) É confiável 6) Está bem preparado para ensinar  \
# 45  A - Concordo Totalmente            A - Concordo Totalmente
# 46  A - Concordo Totalmente            A - Concordo Totalmente
# 47  A - Concordo Totalmente            A - Concordo Totalmente
# 48  A - Concordo Totalmente            A - Concordo Totalmente
# 49  A - Concordo Totalmente            A - Concordo Totalmente
#
#    7) Chega e sai no horário        8) É entusiasmado  ...  \
# 45   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 46   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 47   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 48   A - Concordo Totalmente  A - Concordo Totalmente  ...
# 49   A - Concordo Totalmente  A - Concordo Totalmente  ...
#
#    26) Este/a Instrutor/a me encoraja a falar meu idioma da missão  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#    27) Este/a Instrutor/a fala o idioma da missão o máximo possível  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#    28) Eu me sinto próximo desse Instrutor/a  \
# 45                   A - Concordo Totalmente
# 46                   A - Concordo Totalmente
# 47                   A - Concordo Totalmente
# 48                   A - Concordo Totalmente
# 49                   A - Concordo Totalmente
#
#    29) Respeito e admiro esse Instrutor/a  \
# 45                A - Concordo Totalmente
# 46                A - Concordo Totalmente
# 47                A - Concordo Totalmente
# 48                A - Concordo Totalmente
# 49                A - Concordo Totalmente
#
#    30) Este/a Instrutor/a realmente se preocupa comigo  \
# 45                            A - Concordo Totalmente
# 46                            A - Concordo Totalmente
# 47                            A - Concordo Totalmente
# 48                            A - Concordo Totalmente
# 49                            A - Concordo Totalmente
#
#    31) Este/a Instrutor/a me entende  \
# 45           A - Concordo Totalmente
# 46           A - Concordo Totalmente
# 47           A - Concordo Totalmente
# 48           A - Concordo Totalmente
# 49           A - Concordo Totalmente
#
#    32) Se não houver uma reposta que descreva seu relacionamento com este(a) instrutor(a), então comente sobre isso aqui:  \
# 45                                         Muito bom
# 46                                                NaN
# 47                                              É boa
# 48                                                NaN
# 49  Sou inteiramente grata pelas risadas, pela con...
#
#         33) O que você gosta sobre esse instrutor(a)?  \
# 45                                     Ele ri sempre
# 46                                          Tudo dele
# 47  O carinho ao explicar  o humor a vontade de en...
# 48  A alegria e o entusiasmo em ensinar o evangelh...
# 49  TUDO, mas principalmente, dos testemunhos que ...
#
#    34) Quais sugestões você tem para este(a) instrutor(a)?  \
# 45                                        Ta perfeito
# 46                          Acho que não mudaria nada
# 47                                                NaN
# 48                                                NaN
# 49  Continue sendo sorridente, diligente, atencios...
#
#    35) Comentários e Sugestões. Seu instrutor(a) verá esses comentários depois de sair, mas seu nome NÃO será divulgado.
# 45  Ele é muito inteligente, interativo, preocupad...
# 46  Irmão Vinícius,\nMuito obrigado por tudo. Sou ...
# 47                                                NaN
# 48  Obrigado por sorrir sempre, e por transmitir e...
# 49  Obrigada. Ah é, não pode esquecer que A ORAÇÃO...
#
# [5 rows x 37 columns]

# %%
# 32) Se não houver uma reposta que descreva seu relacionamento com este(a) instrutor(a), então comente sobre isso aqui:
p32 = " ".join(df.iloc[:, 33].dropna())
p32 = p32.replace('!', '').replace('.', '').replace(',', '').lower()
p32
# Out:
# 'son muy geniales :3 melhor amigo muita bem eu amo todos as instutoros porque eles sao muita bem e simpatica tudo bem he is great and fun bom relecionamento com vini foi muito incrível ele realmente consegue transmitir sua alegria para nós  muito bom boa boa espetacular super top  muito bom  é boa sou inteiramente grata pelas risadas pela confiança e pela amizade '

# %%
# 33) O que você gosta sobre esse instrutor(a)?
p33 = " ".join(df.iloc[:, 34].dropna())
p33 = p33.replace('!', '').replace('.', '').replace(',', '').replace('/', ' ').lower()
p33
# Out:
# 'ele é muito gentil e me ajudou bastante para me tornar uma missia melhor o doce espirito que ele tras para nós todas as aulas admiro seu entusiasmo e sua alegria ao ensinar é um excelente professor sus buenas actitudes engraçado e espiritual seu testemunho alegria bondade  ele pode entender ensinar  y fazer sentir o espiritu de uma maneira muito especial e simple always fun to be around and makes the learning fun very funny and entertaining makes every class very fun and i love learning portuguese with him he truly believes in me as a missionary he is fun and i enjoy his class greatly engraçado ele e muita animada todos as dias todos as tempo eu nao entendi mas verdade he is very fun and integrates lots of fun into the lessons he also will take take times to connect to the spirit and focus on the doctrines and principles along with key things in our teachers i love that vinicius is so kind hearted that he showed up everyday of class with a huge smile on his face and he was always ready to teach i know he loves each of us by the way he taught and met all of our needs very happy super fun and has a lot of good stories always laughing and it makes me happy ele é muito feliz e muito muito engraçado ele ajuda meu sinto o espírito e amor de deus ele era um professor divertido e ensinou o que precisávamos bem ele é sempre bom e sempre tem um sorriso no rosto ele faz a aula divertida e agradável ao mesmo tempo ensinando muito e nos mantendo aprendendo ele está sempre feliz e super gentil com a aula i like how funny fun he is i love how he always uses the gospel  irmao vinicius esta sempre rindo e se divertindo ele também sabe quando ficar quieto e ensinar espiritualmente  ele e muito encorajador ele se importa muito irmao vini e muito muito engracado e faz ensinando o evengelho um coisas de alegria possui muito bom humor domínio imenso das escrituras e é muito entusiasmado ele é muito divertido e está sempre rindo carisma o espírito que trás pra aula tudo  carisma o espírito que trás pra aula tudo  ele é muito alegre e sorridente isso nos trás segurança e faz nos sentir bem sempre ele é muito espiritual me ajudou muito a aumentar meu testemunho sobre vários pontos do evangelho  ele tem muito conhecimento e é bem animado positividade e domínio das escrituras ele é muito simpático gentil sabe conversar mostrou que se importa comigo e me ensinou o necessário para eu poder evoluir como missionária que ele é gentil e me ajuda ele é muito feliz ele é muito feliz ele é atencioso e realmente ouve o que nós temos a dizer e nos faz sentir ouvidos compreensivo se preocupa com os missionários quer sempre dar o melhor diligente com os mandamentos dedicado a conhecer mais os mandamentos e bem alegre ele é extremamente espiritual e carismático pude sentir o espirito em todas as aulas e pude fortalecer meu testemunho em cada momento pude aprender muito com ele e sou extremamente grata por seu esforço para nos mostrar e nos testificar diariamente que o evangelho de jesus cristo é verdadeiro e que podemos e devemos compartilhá-lo com todos os filhos de deus  a felicidade dele em ensinar o evangelho de jesus cristo de maneira divertida e espiritual gosto de como ele é diligente e específico no ensino  super compreensivel e dar bons conselhos felicidade  ele só faz rir o nome dele devia ser rirnicius melhor instrutor de todos sua empatia e alegria ele ri sempre  tudo dele o carinho ao explicar  o humor a vontade de ensinar  a alegria e o entusiasmo em ensinar o evangelho da melhor forma tudo mas principalmente dos testemunhos que presta várias vezes na aula'

# %%
# 34) Quais sugestões você tem para este(a) instrutor(a)?
p34 = " ".join(df.iloc[:, 35].dropna())
p34 = p34.replace('!', '').replace('.', '').replace(',', '').replace('/', ' ').replace('\n', '').lower()
p34
# Out:
# "nunca deixar de ser o instrutor que ele é que sigan así y nunca cambién <3 none he does a great job no suggestions no sei eu nao sei? sometimes he can back down on the jokes a little also there were a few times he just repeated what he said slower to explain something he said in portuguese but there still was confusion so it could have been reworded to be explained but usually he was very fun and a very good teacher who was thoughtful in his lessons and such none at the beginning i thought i was kinda overwhelmed cause you would speak a lot of portuguese but now i'm glad you did because i feel like i can speak better because of it  misturar as coisas na classe um pouco mais um pouco mais quebra kkkkkk mais jogos de linguagem when we dont know a word in portuguese instead of just acting out what it is act it out and then say it in english so we can hear it too certifique-se de que o distrito compreende o que deve fazer antes de ir para break-out rooms nunca nenhum alge tempo ele fala rapito e eu  nao entende  continue assim carisma anima muito a aula continue assim 😊 continue sendo sempre esse cara gente boa e amigo amo você e obrigado por seus conselhos e sempre vou fazer a barba kakak  aceite que o cuscuz do nordeste é melhor 0 sugestões quase perfeito :')  não se preocupar com a internet e não se preocupar em pedir ajuda para os missionários sei que sempre temos o que melhorar e como progredir mas acredito que da mesma forma que pude compreender e progredir no meu conhecimento do evangelho e em como ensinar por causa de suas aulas não consigo pensar em nada no que precise melhorar mais  tempo de pausa   e menos fazendeiro  continue sempre assim  nada ta perfeito acho que não mudaria nada continue sendo sorridente diligente atencioso parceiro dos missionários "

# %%
# 35) Comentários e Sugestões. Seu instrutor(a) verá esses comentários depois de sair, mas seu nome NÃO será divulgado.
p35 = " ".join(df.iloc[:, 36].dropna())
p35 = p35.replace('!', '').replace('.', '').replace(',', '').replace('/', ' ').replace('\n', '').lower()
p35
# Out:
# "sempre faça praticas usando os missionarios fiquei sensivel ao ispirito graças a essas praticas ;) seu entusiasmo e seu modo de ensinar son geniales jeje 3 eu amo irmao continue fazendo o que você faz é muito espiritual e engraçado um ótimo instrutor sing to us more i loved how many games we played to learn- you truly gave me a great time in the ctm maybe a suggestion: double check with someone what we are supposed to do before a break out room so we all know what we are doing but otherwise- awesome class bom trabalho irmao vinicius i learned so much from you over these six weeks and had fun doing it continue to teach the way you do because you helped me do something really hard in learning a language and made it fun thank you so much obrigado  voce sao muita legal obrigado por muito bem ensinamentos keep up the good work remember sometimes joking when people are confused can make it harder and sometimes we need a bit more - rephrasing or more context - to fully understand what is being said in portuguese not just the sentence repeated however keep up the good work and fun and happy attitude your the best  thank youi honestly loved my classes and experiences i am so grateful for your fun and funny teaching methods sua aula foi muito divertida e eu gostei de você como professora sua atitude posotiva todos os dias realmente fez disso uma grande experiência e fez o ctm muito melhor voce e muinto legal obrigada por ser ótimo  thank you so so much you helped to make class fun and enjoyable and helped me to learn how to teach in the language  obrigado irmao vini nosso tempo juntos foi tao divertido e obrigado por tudo que voce me ensinou mal posso esperar para chegar ao brasil obrigada muita continue fazendo o que voce faz eu amo voce muito obrigada por todos coisas voce ensinavam meu voce ajuda-me entende o que eu preciso fazer melhor e como ensinar muito muito obrigada eu vou nunca esqueca voce você é muito bom no que faz  aprendi muito com você e com todos do ctm obrigado mesmo tu é o cara obrigado por todo conhecimento compartilhado muito divertido e espiritual obrigada por tudo cara você me ajudou muito aprendi muitas coisas e é isto :') s2  sou muito grata por tudo que aprendi com ele e por tudo que ele me ensinou e me ajudou não se preocupar com a internet e não se preocupar em pedir ajuda para os missionários muito obrigada por cada aula cada dedicação e por realmente amar o evangelho de jesus cristo por compartilhar seu testemunho e ajudar a cada um de nós a sermos missionários melhores por meio de seu exemplo e suas palavras  :) top de mais melhor instrutor que eu poderia ter  irmão vinicius eu te amo mais do que um pote de nutella vc é uma das pessoas mais especiais  que eu já conheci amo o seu trabalho espero que sua vida seja abençoada ps raphael gatão te ama de todo o coração tu é 10 vou te chamar pro meu casamento vou me casar daqui uns 4 anos vlw irmão por tudo tu é 10 gostei muito das aulas foram dinâmicas bem claras e espirituais aprendi muito ele é muito inteligente interativo preocupado ele tem as qualidades certas pra lidar com as pessoas e o conhecimento muito bom para ensinar  irmão viníciusmuito obrigado por tudo sou muito grato pelo seu trabalho e carinho tenho certeza que você será grandemente abençoado pelo seu incrível trabalho obrigado por sorrir sempre e por transmitir essa alegria grata por sua dedicação em ensinar e fazer com que possamos compreender as doutrinas aprendi muito com suas aulas irmão vinicius :) obrigada ah é não pode esquecer que a oração é a chave da vitória"

# %%
stopwords = set(STOPWORDS)
stopwords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
stopwords.update(['de', 'da', 'do', 'dos', 'das', 'e', 'ou', 'que', 'muita', 'muito', 'muitas', 'muitos', 'em', 'o', 'a',
                 'é', 'pelo', 'pela', 'pelos', 'pelas', 'por', 'para', 'todo', 'toda', 'todos', 'todas', 'você', 'sim', 'não',
                 'ele', 'nós', 'nos', 'se', 'bem', 'bom', 'boa', 'muy', 'tudo', 'porque', 'eu', 'sua', 'seu', 'suas', 'seus',
                 'sempre', 'faz', 'um', 'uma', 'os', 'as', 'always', 'never', 'sempre', 'nunca', 'nao', 'mais', 'sei', 'pouco',
                 'sendo', 'assim', 'said', 'voce', 'son', 'sou', 'sao', 'eles', 'realmente', 'consegue', 'instutoros', 'fazer',
                 'missionários', 'sometimes', 'something', 'still', 'suggestions', 'little', 'times', 'irmão', 'irmao',
                  'vinicius'])

# %% [markdown]
# # Se não houver uma reposta que descreva seu relacionamento com este(a) instrutor(a), então comente sobre isso aqui

# %%
wc32 = WordCloud(stopwords=stopwords, background_color='white').generate(p32)
plt.figure()
plt.imshow(wc32, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # O que você gosta sobre esse instrutor(a)?

# %%
wc33 = WordCloud(stopwords=stopwords, background_color='white').generate(p33)
plt.figure()
plt.imshow(wc33, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Quais sugestões você tem para este(a) instrutor(a)?

# %%
wc34 = WordCloud(stopwords=stopwords, background_color='white').generate(p34)
plt.figure()
plt.imshow(wc34, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## Tentando entender um pouco melhor as sugestões dos falantes de inglês

# %%
ing = " ".join(df.loc[df['Qual é seu distrito?'].isin(['26-A ING', '32-B ING']), :].iloc[:, 35].dropna())
ing = ing.lower().replace('?', '').replace('\n', '').replace('.', '').replace(',', '')
wcing = WordCloud(stopwords=stopwords, background_color = 'white').generate(ing)
plt.figure()
plt.imshow(wcing, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
ing
# Out:
# "none he does a great job no suggestions no sei eu nao sei sometimes he can back down on the jokes a little also there were a few times he just repeated what he said slower to explain something he said in portuguese but there still was confusion so it could have been reworded to be explained but usually he was very fun and a very good teacher who was thoughtful in his lessons and such none at the beginning i thought i was kinda overwhelmed cause you would speak a lot of portuguese but now i'm glad you did because i feel like i can speak better because of it  misturar as coisas na classe um pouco mais um pouco mais quebra kkkkkk mais jogos de linguagem when we dont know a word in portuguese instead of just acting out what it is act it out and then say it in english so we can hear it too certifique-se de que o distrito compreende o que deve fazer antes de ir para break-out rooms nunca nenhum alge tempo ele fala rapito e eu  nao entende "

# %%
# Armazenando as sugestões dos falantes de ingLês
suggestions_ing = ['less jokes', 'rewording', 'more breaks', 'more games', 'say in english after you acted out',
                   'make sure they understand before sending them to breakout rooms', 'speak slower']

# %% [markdown]
# ## Agora tentando entender um pouco melhor as sugestões dos falantes de português ou espanhol

# %%
poresp = " ".join(df.loc[~ df['Qual é seu distrito?'].isin(['26-A ING', '32-B ING']), :].iloc[:, 35].dropna())
poresp = poresp.lower().replace(',', '').replace('.', '').replace('!', '')
wcporesp = WordCloud(stopwords=stopwords, background_color = 'white').generate(poresp)
plt.figure()
plt.imshow(wcporesp, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
poresp
# Out:
# "nunca deixar de ser o instrutor que ele é que sigan así y nunca cambién <3 continue assim carisma anima muito a aula continue assim 😊 continue sendo sempre esse cara gente boa e amigo amo você e obrigado por seus conselhos e sempre vou fazer a barba kakak  aceite que o cuscuz do nordeste é melhor 0 sugestões quase perfeito :')  não se preocupar com a internet e não se preocupar em pedir ajuda para os missionários sei que sempre temos o que melhorar e como progredir mas acredito que da mesma forma que pude compreender e progredir no meu conhecimento do evangelho e em como ensinar por causa de suas aulas não consigo pensar em nada no que precise melhorar mais  tempo de pausa   e menos fazendeiro  continue sempre assim  nada ta perfeito acho que não mudaria nada continue sendo sorridente diligente atencioso parceiro dos missionários "

# %% [markdown]
# # Comentários e Sugestões. Seu instrutor(a) verá esses comentários depois de sair, mas seu nome NÃO será divulgado.

# %%
wc35 = WordCloud(stopwords=stopwords, background_color='white').generate(p35)
plt.figure()
plt.imshow(wc35, interpolation='bilinear')
plt.axis("off")
plt.show()
